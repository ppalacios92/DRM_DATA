# %%
# %reset -f 

from LadrunoGraphStyle import set_default_plot_params, main_colors
set_default_plot_params()

# %%
from ShakerMakerResults import ShakerMakerData

import numpy as np
import os

import h5py
import matplotlib.pyplot as plt

# %% [markdown]
# ## Surface simple

# %%
# folder= '/home/pxpalacios/Dropbox/resources/Gaussian_Surface'
folder = r'C:\Dropbox\resources\Gaussian_Surface'

h5drm = os.path.join(folder, 'Gaussian_Surface.h5drm')
h5gf  = os.path.join(folder, 'Gaussian_Surface_gf.h5')
h5map  = os.path.join(folder, 'Gaussian_Surface_map.h5')


surface_gaussian = ShakerMakerData(h5drm)
surface_gaussian.load_gf_database(h5gf)
surface_gaussian.load_map(h5map)

# %%
# resample 
surface_gaussian_resample = surface_gaussian.resample(dt=0.01)
surface_gaussian_resample.plot_node_response(
                                node_id='QA', 
                                data_type='vel', 
                                figsize=(8, 6),
                                factor=1.0,
                                )

# %%
# get_window

surface_gaussian_window= surface_gaussian.get_window(t_start=0.0, t_end=10.0)

surface_gaussian_window.plot_node_response(
                                target_pos=[6 , 8,  0.00],
                                data_type='vel', 
                                figsize=(8, 6),
                                factor=1.0,
                                )

# %%
surface_gaussian_window.plot_domain( 
    xyz_origin=None,
    label_nodes='corners',
    show_calculated=False,
    figsize=(8, 6),
    axis_equal=True,
)

# %%
surface_gaussian_window.plot_domain_calculated_t0(
    subfault='all',
    xyz_origin=None,
    show_calculated_only=True,
    figsize=(8, 6),
    axis_equal=True,
    cmap="viridis",
)

# %%
surface_gaussian_window.plot_gf_connections(
                        node_id='QA',
                        xyz_origin=None,
                        label_nodes='donor_receivers',
                        figsize=(8,6),
                        axis_equal=True)

# %%
# Por ID
surface_gaussian_window.plot_node_response( 
                        node_id=['QA' , 0,100], 
                        data_type='vel', 
                        figsize=(8, 6),
                        factor=1.0,
                        )

# %%
# Por ID
surface_gaussian_window.plot_node_newmark( 
                        node_id=['QA' , 0,100], 
                        data_type='accel', 
                        spectral_type='PSa',
                        figsize=(8, 6),
                        factor=1/9.81,
                        )

# %%
surface_gaussian_window.plot_node_tensor_gf(
                        node_id=['QA'],
                        subfault=0, 
                        figsize=(8, 6),
                        )

# %%
surface_gaussian_window.plot_node_arias(              
                    node_id=['QA' , 0,100],
                    data_type     = 'accel',
                    figsize=(8, 6),
                    factor=1,
                    )

# %%
# Plot surface snapshot
surface_gaussian_window.plot_surface(  time=5.0, 
                            component='resultant', 
                            data_type='vel', 
                            cmap='RdBu_r', 
                            figsize=(8, 8),
                            elev=30, azim=-60, s=20, alpha=0.9,
                            axis_equal=True,)

# %%
# surface_gaussian_window.plot_surface_newmark(
#                         T_target      = 0.0,
#                         component     = 'resultant',
#                         data_type     = 'accel',
#                         spectral_type = 'PSa',
#                         factor        = 1.0/9.81,
#                         cmap          = 'viridis',
#                         figsize       = (8, 6),
#                         # elev          = 35,
#                         # azim          = -60,
#                         s             = 20,
#                         alpha         = 0.85,
#                         axis_equal    = True,
#                         n_jobs        = -2,
# )

# %%
# surface_gaussian_window.plot_surface_arias(
#                     component  = 'z',
#                     data_type  = 'accel',
#                     factor     = 1.0,
#                     cmap       = 'turbo',
#                     figsize       = (8, 6),
#                     elev          = 35,
#                     azim          = -60,
#                     s          = 20,
#                     alpha      = 0.85,
#                     axis_equal = True,
#                     n_jobs     = -2,
# )

# %%
surface_gaussian_window.viewer()
